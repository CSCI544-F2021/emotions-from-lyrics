# %% [markdown]
# # **Sentiment Analysis with Deep Learning using BERT**
#
#
# ## **What is BERT?**
#
# BERT is a large-scale transformer-based Language Model that can be finetuned for a variety of tasks.

# %%
import pandas as pd
import numpy as np
import csv
from nltk.cluster import KMeansClusterer, euclidean_distance
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from itertools import product, filterfalse
from nltk import stem

# %%
my_lyrics_0_20k = pd.read_csv('my_lyrics_0_20k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id', 'artist', 'title', 'emotion','lyrics'])
print(len(my_lyrics_0_20k))
my_lyrics_20k_30k = pd.read_csv('my_lyrics_20k_30k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
print(len(my_lyrics_20k_30k))
my_lyrics_30k_40k = pd.read_csv('my_lyrics_30k_40k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
print(len(my_lyrics_30k_40k))
my_lyrics_40k_50k = pd.read_csv('my_lyrics_40k_50k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
print(len(my_lyrics_40k_50k))
my_lyrics_50k_53k = pd.read_csv('my_lyrics_50k_53k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist', 'title','emotion','lyrics'])
print(len(my_lyrics_50k_53k))
my_lyrics_53k_56k = pd.read_csv('my_lyrics_53k_56k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist', 'title','emotion','lyrics'])
print(len(my_lyrics_53k_56k))
my_lyrics_56k_59k = pd.read_csv('my_lyrics_56k_59k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
print(len(my_lyrics_56k_59k))
my_lyrics_59k = pd.read_csv('my_lyrics_59k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
print(len(my_lyrics_59k))
# Out:
# 20001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/17/jys7jgwn3x37cltk9w8j0l080000gq/T/ipykernel_74350/1887320097.py in <module>
#       1 my_lyrics_0_20k = pd.read_csv('my_lyrics_0_20k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id', 'artist', 'title', 'emotion','lyrics'])
#       2 print(len(my_lyrics_0_20k))
# ----> 3 my_lyrics_20k_30k = pd.read_csv('my_lyrics_20k_30k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
#       4 print(len(my_lyrics_20k_30k))
#       5 my_lyrics_30k_40k = pd.read_csv('my_lyrics_30k_40k.csv', usecols = ['_id', 'albumTitle', 'lastfm_id','artist','title', 'emotion','lyrics'])
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
# ...

# %%
frames = [my_lyrics_0_20k, my_lyrics_20k_30k, my_lyrics_30k_40k, my_lyrics_40k_50k, my_lyrics_50k_53k, my_lyrics_53k_56k, my_lyrics_56k_59k, my_lyrics_59k]
result = pd.concat(frames)

# %%
print(len(result))
result['emotion'].value_counts()
# Out:
# 59112
# calm      16800
# happy     16433
# sad       15812
# energy    10067
# Name: emotion, dtype: int64

# %%
my_pd = result.dropna()
my_pd = my_pd.reset_index(drop = True)
print(len(my_pd))
# Out:
# 56022

# %%
my_pd.to_csv('lyrics_dataset.csv', index = False)
